# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sb
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [10, 10]
ad = pd.read_csv("C:/Users/jhb_f/Desktop/Spring 2018 A/Data Mining/wk3/admission.csv")
#sb.countplot(x='rank', hue='admit', data=ad)
#plt.show()
ad[['gre', 'gpa']]
# Out:
#      gre   gpa
# 0    380  3.61
# 1    660  3.67
# 2    800  4.00
# 3    640  3.19
# 4    520  2.93
# 5    760  3.00
# 6    560  2.98
# 7    400  3.08
# 8    540  3.39
# 9    700  3.92
# 10   800  4.00
# 11   440  3.22
# 12   760  4.00
# 13   700  3.08
# 14   700  4.00
# 15   480  3.44
# 16   780  3.87
# 17   360  2.56
# 18   800  3.75
# 19   540  3.81
# 20   500  3.17
# 21   660  3.63
# 22   600  2.82
# 23   680  3.19
# 24   760  3.35
# 25   800  3.66
# 26   620  3.61
# 27   520  3.74
# 28   780  3.22
# 29   520  3.29
# ..   ...   ...
# 370  540  3.77
# 371  680  3.76
# 372  680  2.42
# 373  620  3.37
# 374  560  3.78
# 375  560  3.49
# 376  620  3.63
# 377  800  4.00
# 378  640  3.12
# 379  540  2.70
# 380  700  3.65
# 381  540  3.49
# 382  540  3.51
# 383  660  4.00
# 384  480  2.62
# 385  420  3.02
# 386  740  3.86
# 387  580  3.36
# 388  640  3.17
# 389  640  3.51
# 390  800  3.05
# 391  660  3.88
# 392  600  3.38
# 393  620  3.75
# 394  460  3.99
# 395  620  4.00
# 396  560  3.04
# 397  460  2.63
# 398  700  3.65
# 399  600  3.89
#
# [400 rows x 2 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
x=ad[['gre', 'gpa']]
y=ad['admit']
x_train ,x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, stratify=y) 
knn = KNeighborsClassifier(n_neighbors = 6)
knn.fit(x_train, y_train)
knn.score(x_test, y_test)
# Out:
# 0.6583333333333333
